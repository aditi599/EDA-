# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\new\Desktop\IMBD.csv")
df
# Out:
#                                                 movie  \
# 0                                         The Witcher
# 1       Mission: Impossible - Dead Reckoning Part One
# 2                                    Sound of Freedom
# 3                                     Secret Invasion
# 4                                Special Ops: Lioness
# ...                                               ...
# 129886                                       Chocatos
# 129887                          Song of the Caballero
# 129888                            The Flaming Forties
# 129889                       The Girl and the Sheriff
# 129890                           The End of the Trail
#
#                                           genre  runtime certificate  rating  \
# 0          Action, Adventure, Drama               60 min           A     8.1
# 1       Action, Adventure, Thriller              163 min          UA     8.0
# 2          Action, Biography, Drama              131 min       PG-13     7.9
# ...

# %% [markdown]
# ### See first 10 entries

# %%
df.head(10)
# Out:
#                                            movie  \
# 0                                    The Witcher
# 1  Mission: Impossible - Dead Reckoning Part One
# 2                               Sound of Freedom
# 3                                Secret Invasion
# 4                           Special Ops: Lioness
# 5                             They Cloned Tyrone
# 6                  Star Trek: Strange New Worlds
# 7                                      One Piece
# 8                                  Twisted Metal
# 9                                      The Flash
#
#                                      genre  runtime certificate  rating  \
# 0     Action, Adventure, Drama               60 min           A     8.1
# 1  Action, Adventure, Thriller              163 min          UA     8.0
# 2     Action, Biography, Drama              131 min       PG-13     7.9
# 3     Action, Adventure, Drama               47 min      UA 16+     6.2
# ...

# %% [markdown]
# ### See last 10 entries

# %%
df.tail(10)
# Out:
#                            movie                                 genre  \
# 129881                 Weary Sun  Drama, Thriller, Western
# 129882               I'm Leaving    Short, Drama, Thriller
# 129883                     Don X                   Western
# 129884                 Just Gone     Short, Drama, Mystery
# 129885           Western Sunrise            Short, Western
# 129886                  Chocatos      Short, Drama, Family
# 129887     Song of the Caballero            Drama, Western
# 129888       The Flaming Forties                   Western
# 129889  The Girl and the Sheriff            Short, Western
# 129890      The End of the Trail            Short, Western
#
#        runtime certificate  rating  \
# 129881  92 min         NaN     NaN
# 129882  13 min         NaN     NaN
# 129883     NaN         NaN     NaN
# 129884  14 min         NaN     NaN
# 129885     NaN         NaN     NaN
# 129886  10 min         NaN     NaN
# 129887  73 min         NaN     NaN
# ...

# %% [markdown]
# ### Storing number of rows and columns in separate variable

# %%
df_rows = df.shape[0]
df_rows
# Out:
# 129891

# %%
df_cols = df.shape[1]
df_cols
# Out:
# 9

# %% [markdown]
# ### Column Names

# %%
df.columns
# Out:
# Index(['movie', 'genre', 'runtime', 'certificate', 'rating', 'stars',
#        'description', 'votes', 'director'],
#       dtype='object')

# %% [markdown]
# ### Checking Data Types

# %%
df.dtypes
# Out:
# movie           object
# genre           object
# runtime         object
# certificate     object
# rating         float64
# stars           object
# description     object
# votes           object
# director        object
# dtype: object

# %% [markdown]
# ### Selecting columns on the basis of their datatypes

# %%
df.select_dtypes(include=['object']).head()
# Out:
#                                            movie  \
# 0                                    The Witcher
# 1  Mission: Impossible - Dead Reckoning Part One
# 2                               Sound of Freedom
# 3                                Secret Invasion
# 4                           Special Ops: Lioness
#
#                                      genre  runtime certificate  \
# 0     Action, Adventure, Drama               60 min           A
# 1  Action, Adventure, Thriller              163 min          UA
# 2     Action, Biography, Drama              131 min       PG-13
# 3     Action, Adventure, Drama               47 min      UA 16+
# 4      Action, Drama, Thriller                  NaN         NaN
#
#                                                stars  \
# 0  ['Henry Cavill, ', 'Freya Allan, ', 'Anya Chal...
# 1  ['Tom Cruise, ', 'Hayley Atwell, ', 'Ving Rham...
# 2  ['Jim Caviezel, ', 'Mira Sorvino, ', 'Bill Cam...
# 3  ['Samuel L. Jackson, ', 'Emilia Clarke, ', 'Do...
# ...

# %%
df.select_dtypes(include=['float']).head()
# Out:
#    rating
# 0     8.1
# 1     8.0
# 2     7.9
# 3     6.2
# 4     7.5

# %% [markdown]
# ### Summarizing DataFrame

# %% [markdown]
# Describe only works on numeric datatype
# For includinf each column of different dtype add include as param

# %%
df.describe()
# Out:
#               rating
# count  114381.000000
# mean        6.521429
# std         1.334240
# min         1.000000
# 25%         5.800000
# 50%         6.700000
# 75%         7.400000
# max        10.000000

# %%
df.describe(include="all")
# Out:
#                movie                    genre runtime certificate  \
# count         129891                   129891  109005       23850
# unique        115988                     2214     571          39
# top     Royal Rumble  Documentary              90 min           R
# freq              22                     5030    4386        6426
# mean             NaN                      NaN     NaN         NaN
# std              NaN                      NaN     NaN         NaN
# min              NaN                      NaN     NaN         NaN
# 25%              NaN                      NaN     NaN         NaN
# 50%              NaN                      NaN     NaN         NaN
# 75%              NaN                      NaN     NaN         NaN
# max              NaN                      NaN     NaN         NaN
#
#                rating              stars   description   votes director
# count   114381.000000             124676        129891  114393    88611
# ...

# %% [markdown]
# ### Value Count

# %%
df['genre'].value_counts()
# Out:
# genre
# Documentary                                 5030
# Music                                       2517
# Western                                     2491
# Animation, Action, Adventure                1977
# Drama, Romance                              1936
#                                             ...
# Drama, Thriller, Horror                        1
# Thriller, Horror, Mystery                      1
# Horror, Crime, Thriller                        1
# Thriller, Drama, Horror                        1
# Sport, Western                                 1
# Name: count, Length: 2214, dtype: int64

# %% [markdown]
# #### For Unique Values

# %%
df['certificate'].unique()
# Out:
# array(['A', 'UA', 'PG-13', 'UA 16+', nan, 'R', 'Not Rated', '16+', '18',
#        '18+', 'U', 'PG', 'UA 13+', '16', '7', 'U/A', '13', '15+', '12+',
#        'U/A 16+', '(Banned)', 'UA 7+', '12', 'All', 'G', 'Unrated',
#        'NC-17', 'Approved', 'M/PG', 'GP', '15', '7+', 'U/A 7+', 'TV-14',
#        'M', '3+', '13+', 'Passed', 'TV-PG', 'X'], dtype=object)

# %% [markdown]
# #### For finding col count of those unique values

# %%
df['certificate'].nunique()
# Out:
# 39

# %% [markdown]
# ### Data Filtering

# %%
df[df['certificate']=='3+']
# Out:
#             movie                                  genre runtime certificate  \
# 18081  Gopal bhar  Animation, Comedy, Family                 NaN          3+
#
#        rating stars                                        description votes  \
# 18081     7.6   NaN  Gopal bhar was a legendary court jester in med...   105
#
#       director
# 18081      NaN

# %%
df[df['certificate']=='U/A 7+']
# Out:
#        movie                                  genre runtime certificate  \
# 12137   Jane          Adventure, Family                 NaN      U/A 7+
# 17038  Blush  Animation, Short, Romance              11 min      U/A 7+
# 95401  Blush  Animation, Short, Romance              11 min      U/A 7+
#
#        rating                                              stars  \
# 12137     6.6  ['Ava Louise Murchison, ', 'Mason Blomberg, ',...
# 17038     7.6                                                NaN
# 95401     7.6                                                NaN
#
#                                              description  votes       director
# 12137  Jane Garcia, a 10-year-old girl and her trusty...    127            NaN
# 17038  A stranded horticulturist-astronaut meets an e...  1,919  ['Joe Mateo']
# 95401  A stranded horticulturist-astronaut meets an e...  1,919             []

# %%
df[df['certificate']=='Not Rated']
# Out:
#                                        movie  \
# 6              Star Trek: Strange New Worlds
# 154                          Superman & Lois
# 508                            The Boondocks
# 523     Escape Room: Tournament of Champions
# 726                          Superhero Movie
# ...                                      ...
# 115713                            Tegeran-43
# 117158                                 Yi yu
# 118137                       Ladakh Warriors
# 121011                          Line Of Duty
# 122018             The Return of Sam McCloud
#
#                                         genre  runtime certificate  rating  \
# 6       Action, Adventure, Sci-Fi               52 min   Not Rated     8.3
# 154      Action, Adventure, Drama               42 min   Not Rated     7.8
# 508     Animation, Action, Comedy               22 min   Not Rated     8.5
# 523     Action, Adventure, Horror               88 min   Not Rated     5.7
# ...

# %% [markdown]
# #### Dropping Duplicates

# %% [markdown]
# Dropping duplicated column wise

# %%
df_subset = df.drop_duplicates(['movie'])
df_subset
# Out:
#                                                 movie  \
# 0                                         The Witcher
# 1       Mission: Impossible - Dead Reckoning Part One
# 2                                    Sound of Freedom
# 3                                     Secret Invasion
# 4                                Special Ops: Lioness
# ...                                               ...
# 129886                                       Chocatos
# 129887                          Song of the Caballero
# 129888                            The Flaming Forties
# 129889                       The Girl and the Sheriff
# 129890                           The End of the Trail
#
#                                           genre  runtime certificate  rating  \
# 0          Action, Adventure, Drama               60 min           A     8.1
# 1       Action, Adventure, Thriller              163 min          UA     8.0
# 2          Action, Biography, Drama              131 min       PG-13     7.9
# ...

# %%
df_subset
# Out:
#                                                 movie  \
# 0                                         The Witcher
# 1       Mission: Impossible - Dead Reckoning Part One
# 2                                    Sound of Freedom
# 3                                     Secret Invasion
# 4                                Special Ops: Lioness
# ...                                               ...
# 129886                                       Chocatos
# 129887                          Song of the Caballero
# 129888                            The Flaming Forties
# 129889                       The Girl and the Sheriff
# 129890                           The End of the Trail
#
#                                           genre  runtime certificate  rating  \
# 0          Action, Adventure, Drama               60 min           A     8.1
# 1       Action, Adventure, Thriller              163 min          UA     8.0
# 2          Action, Biography, Drama              131 min       PG-13     7.9
# ...

# %% [markdown]
# ### Sorting

# %%
df_subset.sort_values(by='runtime')
# Out:
#                                              movie  \
# 100391        Louis Vuitton, Our Journey Connected
# 102991    The Perfectionists: Somebody is Watching
# 111820                                 Two Fencers
# 102966                            La fée aux choux
# 78723   Disney Channel Stars: DuckTales Theme Song
# ...                                            ...
# 129877                                    Red Mask
# 129883                                       Don X
# 129885                             Western Sunrise
# 129889                    The Girl and the Sheriff
# 129890                        The End of the Trail
#
#                                      genre runtime certificate  rating  \
# 100391                   Short               1 min         NaN     5.7
# 102991                   Short               1 min         NaN     8.2
# 111820            Short, Sport               1 min         NaN     4.9
# ...

# %% [markdown]
# ### Missing movie names

# %%
df_subset.isna()
# Out:
#         movie  genre  runtime  certificate  rating  stars  description  votes  \
# 0       False  False    False        False   False  False        False  False
# 1       False  False    False        False   False  False        False  False
# 2       False  False    False        False   False  False        False  False
# 3       False  False    False        False   False  False        False  False
# 4       False  False     True         True   False  False        False  False
# ...       ...    ...      ...          ...     ...    ...          ...    ...
# 129886  False  False    False         True    True   True        False   True
# 129887  False  False    False         True    True  False        False   True
# 129888  False  False    False         True    True  False        False   True
# 129889  False  False     True         True    True  False        False   True
# 129890  False  False     True         True    True   True        False   True
#
#         director
# ...

# %%
df_subset
# Out:
#                                                 movie  \
# 0                                         The Witcher
# 1       Mission: Impossible - Dead Reckoning Part One
# 2                                    Sound of Freedom
# 3                                     Secret Invasion
# 4                                Special Ops: Lioness
# ...                                               ...
# 129886                                       Chocatos
# 129887                          Song of the Caballero
# 129888                            The Flaming Forties
# 129889                       The Girl and the Sheriff
# 129890                           The End of the Trail
#
#                                           genre  runtime certificate  rating  \
# 0          Action, Adventure, Drama               60 min           A     8.1
# 1       Action, Adventure, Thriller              163 min          UA     8.0
# 2          Action, Biography, Drama              131 min       PG-13     7.9
# ...

# %% [markdown]
# #### Working on runtime column for extracing only numeric value

# %%
df_subset['runtime']
# Out:
# 0          60 min
# 1         163 min
# 2         131 min
# 3          47 min
# 4             NaN
#            ...
# 129886     10 min
# 129887     73 min
# 129888     60 min
# 129889        NaN
# 129890        NaN
# Name: runtime, Length: 115988, dtype: object

# %%
df_subset['runtime_min'] = df['runtime'].str.extract(r'(\d+)')
df_subset['runtime_min']
# Out:
# C:\Users\new\AppData\Local\Temp\ipykernel_8376\2791834743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['runtime_min'] = df['runtime'].str.extract(r'(\d+)')
# 0          60
# 1         163
# 2         131
# 3          47
# 4         NaN
#          ...
# 129886     10
# 129887     73
# 129888     60
# 129889    NaN
# 129890    NaN
# Name: runtime_min, Length: 115988, dtype: object

# %%
df_subset['runtime_min']=df_subset['runtime_min'].fillna(0)
# Out:
# C:\Users\new\AppData\Local\Temp\ipykernel_8376\3894586276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['runtime_min']=df_subset['runtime_min'].fillna(0)

# %%
df_subset['runtime_min'].astype('int')
# Out:
# 0          60
# 1         163
# 2         131
# 3          47
# 4           0
#          ...
# 129886     10
# 129887     73
# 129888     60
# 129889      0
# 129890      0
# Name: runtime_min, Length: 115988, dtype: int64

# %%
df_subset
# Out:
#                                                 movie  \
# 0                                         The Witcher
# 1       Mission: Impossible - Dead Reckoning Part One
# 2                                    Sound of Freedom
# 3                                     Secret Invasion
# 4                                Special Ops: Lioness
# ...                                               ...
# 129886                                       Chocatos
# 129887                          Song of the Caballero
# 129888                            The Flaming Forties
# 129889                       The Girl and the Sheriff
# 129890                           The End of the Trail
#
#                                           genre  runtime certificate  rating  \
# 0          Action, Adventure, Drama               60 min           A     8.1
# 1       Action, Adventure, Thriller              163 min          UA     8.0
# 2          Action, Biography, Drama              131 min       PG-13     7.9
# ...

# %% [markdown]
# Now as we have extracted only the numeric col with min we can drop the other object dtype col

# %%
df_subset
# Out:
#                                                 movie  \
# 0                                         The Witcher
# 1       Mission: Impossible - Dead Reckoning Part One
# 2                                    Sound of Freedom
# 3                                     Secret Invasion
# 4                                Special Ops: Lioness
# ...                                               ...
# 129886                                       Chocatos
# 129887                          Song of the Caballero
# 129888                            The Flaming Forties
# 129889                       The Girl and the Sheriff
# 129890                           The End of the Trail
#
#                                           genre  runtime certificate  rating  \
# 0          Action, Adventure, Drama               60 min           A     8.1
# 1       Action, Adventure, Thriller              163 min          UA     8.0
# 2          Action, Biography, Drama              131 min       PG-13     7.9
# ...

# %%
df_subset= df_subset.drop('runtime',axis=1)

# %%
df_subset
# Out:
#                                                 movie  \
# 0                                         The Witcher
# 1       Mission: Impossible - Dead Reckoning Part One
# 2                                    Sound of Freedom
# 3                                     Secret Invasion
# 4                                Special Ops: Lioness
# ...                                               ...
# 129886                                       Chocatos
# 129887                          Song of the Caballero
# 129888                            The Flaming Forties
# 129889                       The Girl and the Sheriff
# 129890                           The End of the Trail
#
#                                           genre certificate  rating  \
# 0          Action, Adventure, Drama                       A     8.1
# 1       Action, Adventure, Thriller                      UA     8.0
# 2          Action, Biography, Drama                   PG-13     7.9
# ...
