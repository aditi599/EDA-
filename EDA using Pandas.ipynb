# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Dataset From Kaggle

# %%
df=pd.read_csv('C:/Users/new/Desktop/data/health_data.csv')
df
# Out:
#        Unnamed: 0       id      age  gender  height  weight  ap_hi  ap_lo  \
# 0               0      0.0  18393.0       1   168.0    62.0  110.0   80.0
# 1               1      1.0  20228.0       0   156.0    85.0  140.0   90.0
# 2               2      2.0  18857.0       0   165.0    64.0  130.0   70.0
# 3               3      3.0  17623.0       1   169.0    82.0  150.0  100.0
# 4               4      4.0  17474.0       0   156.0    56.0  100.0   60.0
# ...           ...      ...      ...     ...     ...     ...    ...    ...
# 69995       69995  99993.0  19240.0       1   168.0    76.0  120.0   80.0
# 69996       69996  99995.0  22601.0       0   158.0   126.0  140.0   90.0
# 69997       69997  99996.0  19066.0       1   183.0   105.0  180.0   90.0
# 69998       69998  99998.0  22431.0       0   163.0    72.0  135.0   80.0
# 69999       69999  99999.0  20540.0       0   170.0    72.0  120.0   80.0
#
#        cholesterol  gluc  smoke  alco  active  cardio
# ...

# %% [markdown]
# Checking the number of rows & columns present in our dataset

# %%
df.shape
# Out:
# (70000, 14)

# %% [markdown]
# Getting tge summary of all the columns in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   70000 non-null  int64
#  1   id           70000 non-null  float64
#  2   age          70000 non-null  float64
#  3   gender       70000 non-null  int64
#  4   height       70000 non-null  float64
#  5   weight       70000 non-null  float64
#  6   ap_hi        70000 non-null  float64
#  7   ap_lo        70000 non-null  float64
#  8   cholesterol  70000 non-null  int64
#  9   gluc         70000 non-null  int64
#  10  smoke        70000 non-null  int64
#  11  alco         70000 non-null  int64
#  12  active       70000 non-null  int64
#  13  cardio       70000 non-null  int64
# dtypes: float64(6), int64(8)
# memory usage: 7.5 MB

# %% [markdown]
# Checking what are the datatypes in our dataset

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# id             float64
# age            float64
# gender           int64
# height         float64
# weight         float64
# ap_hi          float64
# ap_lo          float64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %% [markdown]
# Getting the summary of all the statistical values, that will be only shown for the numerical values present in dataset

# %%
df.describe()
# Out:
#          Unnamed: 0            id           age        gender        height  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   34999.500000  49972.419900  19468.865814      0.349571    164.359229
# std    20207.403759  28851.302323   2467.251667      0.476838      8.210126
# min        0.000000      0.000000  10798.000000      0.000000     55.000000
# 25%    17499.750000  25006.750000  17664.000000      0.000000    159.000000
# 50%    34999.500000  50001.500000  19703.000000      0.000000    165.000000
# 75%    52499.250000  74889.250000  21327.000000      1.000000    170.000000
# max    69999.000000  99999.000000  23713.000000      1.000000    250.000000
#
#              weight         ap_hi         ap_lo   cholesterol          gluc  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      74.205690    128.817286     96.630414      0.366871      0.226457
# ...

# %% [markdown]
# Setting up the floating values

# %%
pd.set_option('display.float_format', lambda x: '%.2f' %x)

# %% [markdown]
# Getting all the column names present in data

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'age', 'gender', 'height', 'weight', 'ap_hi',
#        'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %% [markdown]
# Arranging the naming convention of the columns by rename function

# %%
df.rename(columns={'Unnamed: 0' : 'index'},inplace=True)

# %%
df
# Out:
#        index       id      age  gender  height  weight  ap_hi  ap_lo  \
# 0          0     0.00 18393.00       1  168.00   62.00 110.00  80.00
# 1          1     1.00 20228.00       0  156.00   85.00 140.00  90.00
# 2          2     2.00 18857.00       0  165.00   64.00 130.00  70.00
# 3          3     3.00 17623.00       1  169.00   82.00 150.00 100.00
# 4          4     4.00 17474.00       0  156.00   56.00 100.00  60.00
# ...      ...      ...      ...     ...     ...     ...    ...    ...
# 69995  69995 99993.00 19240.00       1  168.00   76.00 120.00  80.00
# 69996  69996 99995.00 22601.00       0  158.00  126.00 140.00  90.00
# 69997  69997 99996.00 19066.00       1  183.00  105.00 180.00  90.00
# 69998  69998 99998.00 22431.00       0  163.00   72.00 135.00  80.00
# 69999  69999 99999.00 20540.00       0  170.00   72.00 120.00  80.00
#
#        cholesterol  gluc  smoke  alco  active  cardio
# 0                0     0      0     0       1       0
# ...

# %% [markdown]
# Setting up the index, with set_index function

# %%
df.set_index('index')
# Out:
#             id      age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# index
# 0         0.00 18393.00       1  168.00   62.00 110.00  80.00            0
# 1         1.00 20228.00       0  156.00   85.00 140.00  90.00            2
# 2         2.00 18857.00       0  165.00   64.00 130.00  70.00            2
# 3         3.00 17623.00       1  169.00   82.00 150.00 100.00            0
# 4         4.00 17474.00       0  156.00   56.00 100.00  60.00            0
# ...        ...      ...     ...     ...     ...    ...    ...          ...
# 69995 99993.00 19240.00       1  168.00   76.00 120.00  80.00            0
# 69996 99995.00 22601.00       0  158.00  126.00 140.00  90.00            1
# 69997 99996.00 19066.00       1  183.00  105.00 180.00  90.00            2
# 69998 99998.00 22431.00       0  163.00   72.00 135.00  80.00            0
# 69999 99999.00 20540.00       0  170.00   72.00 120.00  80.00            1
#
#        gluc  smoke  alco  active  cardio
# index
# ...

# %% [markdown]
# Changing the datatypes with the function astype

# %%
df['id']=df['id'].astype(int)

# %%
df
# Out:
#        index     id      age  gender  height  weight  ap_hi  ap_lo  \
# 0          0      0 18393.00       1  168.00   62.00 110.00  80.00
# 1          1      1 20228.00       0  156.00   85.00 140.00  90.00
# 2          2      2 18857.00       0  165.00   64.00 130.00  70.00
# 3          3      3 17623.00       1  169.00   82.00 150.00 100.00
# 4          4      4 17474.00       0  156.00   56.00 100.00  60.00
# ...      ...    ...      ...     ...     ...     ...    ...    ...
# 69995  69995  99993 19240.00       1  168.00   76.00 120.00  80.00
# 69996  69996  99995 22601.00       0  158.00  126.00 140.00  90.00
# 69997  69997  99996 19066.00       1  183.00  105.00 180.00  90.00
# 69998  69998  99998 22431.00       0  163.00   72.00 135.00  80.00
# 69999  69999  99999 20540.00       0  170.00   72.00 120.00  80.00
#
#        cholesterol  gluc  smoke  alco  active  cardio
# 0                0     0      0     0       1       0
# ...

# %% [markdown]
# With inplace=True , data will get modified permanently in the same source without making its copy

# %%
df.set_index('index',inplace=True)

# %%
df
# Out:
#           id      age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# index
# 0          0 18393.00       1  168.00   62.00 110.00  80.00            0
# 1          1 20228.00       0  156.00   85.00 140.00  90.00            2
# 2          2 18857.00       0  165.00   64.00 130.00  70.00            2
# 3          3 17623.00       1  169.00   82.00 150.00 100.00            0
# 4          4 17474.00       0  156.00   56.00 100.00  60.00            0
# ...      ...      ...     ...     ...     ...    ...    ...          ...
# 69995  99993 19240.00       1  168.00   76.00 120.00  80.00            0
# 69996  99995 22601.00       0  158.00  126.00 140.00  90.00            1
# 69997  99996 19066.00       1  183.00  105.00 180.00  90.00            2
# 69998  99998 22431.00       0  163.00   72.00 135.00  80.00            0
# 69999  99999 20540.00       0  170.00   72.00 120.00  80.00            1
#
#        gluc  smoke  alco  active  cardio
# index
# ...

# %% [markdown]
# Checking the number of unique values that are present in particular column as column value

# %%
df.nunique()
# Out:
# id             70000
# age             8076
# gender             2
# height           109
# weight           287
# ap_hi            153
# ap_lo            157
# cholesterol        3
# gluc               3
# smoke              2
# alco               2
# active             2
# cardio             2
# dtype: int64

# %%
df
# Out:
#           id      age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# index
# 0          0 18393.00       1  168.00   62.00 110.00  80.00            0
# 1          1 20228.00       0  156.00   85.00 140.00  90.00            2
# 2          2 18857.00       0  165.00   64.00 130.00  70.00            2
# 3          3 17623.00       1  169.00   82.00 150.00 100.00            0
# 4          4 17474.00       0  156.00   56.00 100.00  60.00            0
# ...      ...      ...     ...     ...     ...    ...    ...          ...
# 69995  99993 19240.00       1  168.00   76.00 120.00  80.00            0
# 69996  99995 22601.00       0  158.00  126.00 140.00  90.00            1
# 69997  99996 19066.00       1  183.00  105.00 180.00  90.00            2
# 69998  99998 22431.00       0  163.00   72.00 135.00  80.00            0
# 69999  99999 20540.00       0  170.00   72.00 120.00  80.00            1
#
#        gluc  smoke  alco  active  cardio
# index
# ...

# %% [markdown]
# Modifying data, where the value doesnot make any sense
# Like here, the id is rename as patient_id

# %%
df.rename(columns={'id':'patient_id'})
# Out:
#        patient_id      age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# index
# 0               0 18393.00       1  168.00   62.00 110.00  80.00            0
# 1               1 20228.00       0  156.00   85.00 140.00  90.00            2
# 2               2 18857.00       0  165.00   64.00 130.00  70.00            2
# 3               3 17623.00       1  169.00   82.00 150.00 100.00            0
# 4               4 17474.00       0  156.00   56.00 100.00  60.00            0
# ...           ...      ...     ...     ...     ...    ...    ...          ...
# 69995       99993 19240.00       1  168.00   76.00 120.00  80.00            0
# 69996       99995 22601.00       0  158.00  126.00 140.00  90.00            1
# 69997       99996 19066.00       1  183.00  105.00 180.00  90.00            2
# 69998       99998 22431.00       0  163.00   72.00 135.00  80.00            0
# 69999       99999 20540.00       0  170.00   72.00 120.00  80.00            1
#
# ...

# %% [markdown]
# Age was present as the reference of number of days, so they were converted in years

# %%
df['age']=df['age']/365

# %%
df
# Out:
#           id   age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# index
# 0          0 50.39       1  168.00   62.00 110.00  80.00            0     0
# 1          1 55.42       0  156.00   85.00 140.00  90.00            2     0
# 2          2 51.66       0  165.00   64.00 130.00  70.00            2     0
# 3          3 48.28       1  169.00   82.00 150.00 100.00            0     0
# 4          4 47.87       0  156.00   56.00 100.00  60.00            0     0
# ...      ...   ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993 52.71       1  168.00   76.00 120.00  80.00            0     0
# 69996  99995 61.92       0  158.00  126.00 140.00  90.00            1     1
# 69997  99996 52.24       1  183.00  105.00 180.00  90.00            2     0
# 69998  99998 61.45       0  163.00   72.00 135.00  80.00            0     1
# 69999  99999 56.27       0  170.00   72.00 120.00  80.00            1     0
#
#        smoke  alco  active  cardio
# index
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %% [markdown]
# Now the age is being rounded up with the closest integeral number with the numpy function of ceil, we can also convert it with pandas round() function

# %%
df['age']=np.ceil(df['age'])

# %% [markdown]
# Again the datatype of float is converted in integer

# %%
df['age']=df['age'].astype(int)
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# index
# 0          0   51       1  168.00   62.00 110.00  80.00            0     0
# 1          1   56       0  156.00   85.00 140.00  90.00            2     0
# 2          2   52       0  165.00   64.00 130.00  70.00            2     0
# 3          3   49       1  169.00   82.00 150.00 100.00            0     0
# 4          4   48       0  156.00   56.00 100.00  60.00            0     0
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53       1  168.00   76.00 120.00  80.00            0     0
# 69996  99995   62       0  158.00  126.00 140.00  90.00            1     1
# 69997  99996   53       1  183.00  105.00 180.00  90.00            2     0
# 69998  99998   62       0  163.00   72.00 135.00  80.00            0     1
# 69999  99999   57       0  170.00   72.00 120.00  80.00            1     0
#
#        smoke  alco  active  cardio
# index
# ...

# %% [markdown]
# The value of 1 & 0 is convereted as Male & Female with replace func

# %%
df['gender'] = df['gender'].replace({1:'Female', 0:'Male'})

# %% [markdown]
# Convereted from int to string datatype

# %%
df['gender'] = df['gender'].astype('str')

# %%
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# index
# 0          0   51  Female  168.00   62.00 110.00  80.00            0     0
# 1          1   56    Male  156.00   85.00 140.00  90.00            2     0
# 2          2   52    Male  165.00   64.00 130.00  70.00            2     0
# 3          3   49  Female  169.00   82.00 150.00 100.00            0     0
# 4          4   48    Male  156.00   56.00 100.00  60.00            0     0
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53  Female  168.00   76.00 120.00  80.00            0     0
# 69996  99995   62    Male  158.00  126.00 140.00  90.00            1     1
# 69997  99996   53  Female  183.00  105.00 180.00  90.00            2     0
# 69998  99998   62    Male  163.00   72.00 135.00  80.00            0     1
# 69999  99999   57    Male  170.00   72.00 120.00  80.00            1     0
#
#        smoke  alco  active  cardio
# index
# ...

# %%
df.dtypes
# Out:
# id               int64
# age              int64
# gender          object
# height         float64
# weight         float64
# ap_hi          float64
# ap_lo          float64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# index
# 0          0   51  Female  168.00   62.00 110.00  80.00            0     0
# 1          1   56    Male  156.00   85.00 140.00  90.00            2     0
# 2          2   52    Male  165.00   64.00 130.00  70.00            2     0
# 3          3   49  Female  169.00   82.00 150.00 100.00            0     0
# 4          4   48    Male  156.00   56.00 100.00  60.00            0     0
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53  Female  168.00   76.00 120.00  80.00            0     0
# 69996  99995   62    Male  158.00  126.00 140.00  90.00            1     1
# 69997  99996   53  Female  183.00  105.00 180.00  90.00            2     0
# 69998  99998   62    Male  163.00   72.00 135.00  80.00            0     1
# 69999  99999   57    Male  170.00   72.00 120.00  80.00            1     0
#
#        smoke  alco  active  cardio
# index
# ...

# %% [markdown]
# Checking if there any outliers in the age column with boxplot

# %%
plt.figure(figsize=(10,8))
df.boxplot(column='age')
plt.show()
